# %% [markdown]
# ## Steps
# 1. Connect
# 2. Exec DELETE
# 3. Commit
# 4. Close

# %%
# !python delete.py
# Out:
# The number of deleted rows:  1

# %% [markdown]
# ```
#                                   ^
# suppliers=# SELECT * FROM parts WHERE part_id <5;
#  part_id | part_name
# ---------+-----------
#        1 | Antenna
#        3 | LTE Modem
#        4 | SIM Tray
# (3 rows)
# ```
