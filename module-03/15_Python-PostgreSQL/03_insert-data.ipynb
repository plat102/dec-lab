# %% [markdown]
# ## Steps
# 1. Connect
# 2. Create a cursor
# 3. Execute INSERT statement
# 4. Commit the transaction
# 5. Obtain inserted IDs

# %%
# !python insert.py

# %% [markdown]
# ## Verify result
#
# ```
# suppliers=# SELECT * FROM vendors;
#  vendor_id |          vendor_name
# -----------+-------------------------------
#          1 | 3M Co.
#          2 | AKM Semiconductor Inc.
#          3 | Asahi Glass Co Ltd.
#          4 | Daikin Industries Ltd.
#          5 | Dynacast International Inc.
#          6 | Foster Electric Co. Ltd.
#          7 | Murata Manufacturing Co. Ltd.
# (7 rows)
#
# ```

# %% [markdown]
# double insert?
#
# ```
# suppliers=# SELECT * FROM vendors;
#  vendor_id |          vendor_name
# -----------+-------------------------------
#          1 | 3M Co.
#          2 | AKM Semiconductor Inc.
#          3 | Asahi Glass Co Ltd.
#          4 | Daikin Industries Ltd.
#          5 | Dynacast International Inc.
#          6 | Foster Electric Co. Ltd.
#          7 | Murata Manufacturing Co. Ltd.
#          8 | 3M Co.
#          9 | AKM Semiconductor Inc.
#         10 | Asahi Glass Co Ltd.
#         11 | Daikin Industries Ltd.
#         12 | Dynacast International Inc.
#         13 | Foster Electric Co. Ltd.
#         14 | Murata Manufacturing Co. Ltd.
# (14 rows)
# ```

# %% [markdown]
# ## Use execute_values for bulk insert
# - https://naysan.ca/2020/05/16/pandas-to-postgresql-using-psycopg2-bulk-insert-using-execute_values/
# - https://www.geeksforgeeks.org/python/python-psycopg2-insert-multiple-rows-with-one-query/

# %%
# !python insert.py
# Out:
# 58
# [(59, 'AKM Semiconductor Inc.'), (60, 'Asahi Glass Co Ltd.'), (61, 'Daikin Industries Ltd.'), (62, 'Dynacast International Inc.'), (63, 'Foster Electric Co. Ltd.'), (64, 'Murata Manufacturing Co. Ltd.')]
# [59, 60, 61, 62, 63, 64]
