# %% [markdown]
# ## Create function
#
# ```
# psql -U postgres -d suppliers
#
# suppliers=# CREATE OR REPLACE FUNCTION get_parts_by_vendor(id INTEGER)
#   RETURNS TABLE(part_id INTEGER, part_name VARCHAR) AS
# $$
# BEGIN
#  RETURN QUERY
#
#  SELECT parts.part_id, parts.part_name
#  FROM parts
#  INNER JOIN vendor_parts on vendor_parts.part_id = parts.part_id
#  WHERE vendor_id = id;
#
# END; $$
#
# LANGUAGE plpgsql;
# CREATE FUNCTION
# ```

# %% [markdown]
# ## Call function

# %%
# !python call_function.py
# Out:
# [(2, 'Home Button'), (3, 'LTE Modem'), (4, 'SIM Tray'), (14, 'SIM Tray'), (18, 'Home Button'), (19, 'LTE Modem')]
