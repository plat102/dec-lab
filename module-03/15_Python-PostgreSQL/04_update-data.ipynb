# %% [markdown]
# ## Steps
# 1. Connect
# 2. Create a cursor
# 3. Execute UPDATE statement
# 4. Commit the transaction
# 5. Obtain updated rows IDs

# %%
# !python update.py

# %% [markdown]
# ## Verify
#
# ```sh
# suppliers=# SELECT
#   *
# FROM
#   vendors
# WHERE
#   vendor_id = 1;
#  vendor_id | vendor_name
# -----------+-------------
#          1 | 3M Corp
# (1 row)
# ```
