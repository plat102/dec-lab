# %% [markdown]
# ## Insert
# Steps:
# 1. Read from a file
# 2. Connect
# 3. Create cursor
# 4. Execute INSERT, use Binary object as input data
# 5. Commit

# %%
# !python write_blob.py
# Out:
# Traceback (most recent call last):
#   File "/home/thu/repo/dec-lab/module-03/15_Python-PostgreSQL/write_blob.py", line 30, in <module>
#     write_blob(1, 'images/input/simtray.png', 'png')
#   File "/home/thu/repo/dec-lab/module-03/15_Python-PostgreSQL/write_blob.py", line 11, in write_blob
#     data = open(path_to_file, 'rb').read()
#            ^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'images/input/simtray.png'

# %%
# !python write_blob.py

# %% [markdown]
# ## Read
# ~ Read from a table

# %%
# !python read_blob.py
# Out:
# Blob: ('Antenna', 'png', <memory at 0x7136fdf36740>)
# [Errno 2] No such file or directory: 'images/output/Antenna.png'
# Blob: ('Home Button', 'png', <memory at 0x7136fdf36740>)
# [Errno 2] No such file or directory: 'images/output/Home Button.png'

# %%
# !mkdir -p images/output

# %%
# !python read_blob.py
# Out:
# Blob: ('Antenna', 'png', <memory at 0x79e494d36740>)
# Blob: ('Home Button', 'png', <memory at 0x79e494d36740>)
