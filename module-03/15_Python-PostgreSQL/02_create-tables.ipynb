# %% [markdown]
# ## Steps
# 1. Connect
# 2. Create a cursor
# 3. Execute CREATE TABLE
# 4. Close the connection

# %%
# !python create_tables.py

# %% [markdown]
# ## Verify tables created
# ```shell
# (dec-lab-py3.12) ➜  15_Python-PostgreSQL git:(main) ✗ psql -U postgres -h localhost
# Password for user postgres:
# psql (18.1 (Ubuntu 18.1-1.pgdg24.04+2))
# SSL connection (protocol: TLSv1.3, cipher: TLS_AES_256_GCM_SHA384, compression: off, ALPN: postgresql)
# Type "help" for help.
#
# postgres=# \c
# SSL connection (protocol: TLSv1.3, cipher: TLS_AES_256_GCM_SHA384, compression: off, ALPN: postgresql)
# You are now connected to database "postgres" as user "postgres".
# postgres=# \c suppliers
# SSL connection (protocol: TLSv1.3, cipher: TLS_AES_256_GCM_SHA384, compression: off, ALPN: postgresql)
# You are now connected to database "suppliers" as user "postgres".
# suppliers=# \dt
#               List of tables
#  Schema |     Name      | Type  |  Owner
# --------+---------------+-------+----------
#  public | part_drawings | table | postgres
#  public | parts         | table | postgres
#  public | vendor_parts  | table | postgres
#  public | vendors       | table | postgres
# ```
