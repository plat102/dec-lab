# %%
import requests
import io

import pandas as pd

# %%
DATA_URL = 'https://file.notion.so/f/f/27250981-a51e-4c6e-96ba-f627e96b612e/12ece2ee-e456-4085-b7d3-d4cab5c6102d/data.csv?table=block&id=2921ee83-6605-8053-b465-d3f1d761a537&spaceId=27250981-a51e-4c6e-96ba-f627e96b612e&expirationTimestamp=1765281600000&signature=SjJ-F2KJqjRI0T5sVxYq1IIBs3yo5yb8Z6YQ_wVR-9I&downloadName=data.csv'

# %%
res = requests.get(DATA_URL)
if res.status_code == 200:
    df = pd.read_csv(io.StringIO(res.content.decode('utf-8')))

print(df.info())
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1933 entries, 0 to 1932
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   created_date      1933 non-null   object
#  1   job_title         1933 non-null   object
#  2   company           1933 non-null   object
#  3   salary            1933 non-null   object
#  4   address           1933 non-null   object
#  5   time              1933 non-null   object
#  6   link_description  1933 non-null   object
# dtypes: object(7)
# memory usage: 105.8+ KB
# None
#      created_date                                          job_title  \
# 0      2023-08-01                                   Business Analyst
# 1      2023-08-01  Nhân Viên Lập Trình Phần Mềm - Thu Nhập Từ 10 ...
# 2      2023-08-01                        .Net Developer (N3) | T9160
# 3      2023-08-01  Project Manager (Tiếng Anh Giao Tiếp, Từ 1 Năm...
# 4      2023-08-01  Devops/Sre - Chuyên Viên Quản Trị Hệ Thống/Aut...
# ...           ...                                                ...
# 1928   2023-08-01                               Thực Tập Sinh Dotnet
# 1929   2023-08-01  Thực Tập Sinh Kỹ Thuật Máy Tính - Phần Cứng - ...
# 1930   2023-08-01                                    Project Manager
# 1931   2023-08-01                    Project Manager (Quản Lý Dự Án)
# 1932   2023-08-01                                       IT Fullstack
#
#                                                 company         salary  \
# 0                       Công ty TNHH Công nghệ số Adamo  10 - 20 triệu
# 1                      Công ty TNHH Đầu Tư Công Nghệ ST  10 - 20 triệu
# 2                               Công ty TNHH CMC GLOBAL     Thoả thuận
# 3                     CÔNG TY CỔ PHẦN CÔNG NGHỆ SOTATEK   Tới 35 triệu
# 4                       Công ty Cổ phần Thời Trang Yody   Tới 50 triệu
# ...                                                 ...            ...
# 1928  Công ty TNHH 1 thành viên công nghệ và truyền ...     Thoả thuận
# 1929             Công Ty Cổ Phần Đầu Tư Công Nghệ Hacom   Trên 3 triệu
# 1930          Công ty CP Nghiên cứu và phát triển Fabbi   Tới 50 triệu
# 1931         CÔNG TY CỔ PHẦN TẬP ĐOÀN MARKETING BOOSTGO     Thoả thuận
# 1932         CÔNG TY CỔ PHẦN TẬP ĐOÀN MARKETING BOOSTGO     Thoả thuận
#
#                                           address  \
# 0                                          Hà Nội
# 1                                     Hồ Chí Minh
# 2                                       Toàn Quốc
# 3                                Hà Nội: Cầu Giấy
# 4     Hà Nội: Thanh Xuân: Hải Dương: TP Hải Dương
# ...                                           ...
# 1928      Hà Nội: Thanh Xuân: Hồ Chí Minh: Quận 1
# 1929                    Hà Nội: Hà Đông, Cầu Giấy
# 1930                                       Hà Nội
# 1931                                       Hà Nội
# 1932                                       Hà Nội
#
#                              time  \
# 0        Còn 25 ngày để ứng tuyển
# 1        Còn 91 ngày để ứng tuyển
# 2        Còn 30 ngày để ứng tuyển
# 3        Còn 25 ngày để ứng tuyển
# 4        Còn 30 ngày để ứng tuyển
# ...                           ...
# 1928      Còn 4 ngày để ứng tuyển
# 1929     Còn 26 ngày để ứng tuyển
# 1930     Còn 29 ngày để ứng tuyển
# 1931    Còn 152 ngày để ứng tuyển
# 1932  Còn 10014 ngày để ứng tuyển
#
#                                        link_description
# 0     https://www.topcv.vn/viec-lam/business-analyst...
# 1     https://www.topcv.vn/viec-lam/nhan-vien-lap-tr...
# 2     https://www.topcv.vn/viec-lam/net-developer-n3...
# 3     https://www.topcv.vn/viec-lam/project-manager-...
# 4     https://www.topcv.vn/viec-lam/devops-sre-chuye...
# ...                                                 ...
# 1928  https://www.topcv.vn/viec-lam/thuc-tap-sinh-do...
# 1929  https://www.topcv.vn/viec-lam/thuc-tap-sinh-ky...
# 1930  https://www.topcv.vn/viec-lam/project-manager/...
# 1931  https://www.topcv.vn/viec-lam/project-manager-...
# 1932  https://www.topcv.vn/viec-lam/it-fullstack/636...
#
# [1933 rows x 7 columns]

# %%
df.describe()
# Out:
#        created_date     job_title       company      salary           address  \
# count          1933          1933          1933        1933              1933
# unique            1          1607           904         283               180
# top      2023-08-01  Nhân Viên IT  FPT Software  Thoả thuận  Hà Nội: Cầu Giấy
# freq           1933            24            71         710               326
#
#                             time  \
# count                       1933
# unique                        60
# top     Còn 30 ngày để ứng tuyển
# freq                         583
#
#                                          link_description
# count                                                1933
# unique                                               1933
# top     https://www.topcv.vn/viec-lam/business-analyst...
# freq                                                    1

# %% [markdown]
# ## Yêu cầu 1: Chuẩn hóa và làm sạch dữ liệu
#
# 1. Chuẩn hóa cột salary về dạng số, xử lý các giá trị như "Thoả thuận", "Trên X triệu", "X - Y triệu", "Tới X triệu", etc.
# 2. Tạo thêm các cột phụ: min_salary, max_salary, salary_unit (VND/USD)
# 3. Xử lý cột address để tách thành city và district
# 4. Chuẩn hóa job_title để gom nhóm các vị trí tương tự (ví dụ: "Software Engineer", "Developer", "Programmer" có thể gom vào một nhóm)

# %%
from helpers import extract_salary_info

# %%
extract_salary_info
# Out:
# <function helpers.extract_salary_info(value: str) -> dict[str, typing.Any]>

# %%
df['salary'].apply(extract_salary_info)
# Out:
# 0       {'num': 15.0, 'min': 10.0, 'max': 20.0, 'unit'...
# 1       {'num': 15.0, 'min': 10.0, 'max': 20.0, 'unit'...
# 2                                           {'num': None}
# 3       {'num': 35.0, 'min': None, 'max': 35.0, 'unit'...
# 4       {'num': 50.0, 'min': None, 'max': 50.0, 'unit'...
#                               ...
# 1928                                        {'num': None}
# 1929    {'num': 3.0, 'min': 3.0, 'max': None, 'unit': ...
# 1930    {'num': 50.0, 'min': None, 'max': 50.0, 'unit'...
# 1931                                        {'num': None}
# 1932                                        {'num': None}
# Name: salary, Length: 1933, dtype: object

# %%
df['salary_info'] = df['salary'].apply(extract_salary_info)
df['salary_num'] = df['salary_info'].apply(lambda x: x.get('num')*(10**6)
    if (x.get('num') and 'VND' in x.get('unit')) else None)
df['min_salary'] = df['salary_info'].apply(lambda x: x.get('min')*(10**6) if x.get('unit') == 'VND' else x.get('min'))
df['max_salary'] = df['salary_info'].apply(lambda x: x.get('max')*(10**6) if x.get('unit') == 'VND' else x.get('max'))
df['salary_unit'] = df['salary_info'].apply(lambda  x: x.get('unit'))

df.head(10)
# Out:
#   created_date                                          job_title  \
# 0   2023-08-01                                   Business Analyst
# 1   2023-08-01  Nhân Viên Lập Trình Phần Mềm - Thu Nhập Từ 10 ...
# 2   2023-08-01                        .Net Developer (N3) | T9160
# 3   2023-08-01  Project Manager (Tiếng Anh Giao Tiếp, Từ 1 Năm...
# 4   2023-08-01  Devops/Sre - Chuyên Viên Quản Trị Hệ Thống/Aut...
# 5   2023-08-01                 Angularjs (Từ 1.5 Năm Kinh Nghiệm)
# 6   2023-08-01                             IT Application Support
# 7   2023-08-01                  Thực Tập Sinh Lập Trình Viên .Net
# 8   2023-08-01                     Chuyên Viên Lập Trình Phần Mềm
# 9   2023-08-01                       Thực Tập Lập Trình Viên .Net
#
#                                              company         salary  \
# 0                    Công ty TNHH Công nghệ số Adamo  10 - 20 triệu
# 1                   Công ty TNHH Đầu Tư Công Nghệ ST  10 - 20 triệu
# 2                            Công ty TNHH CMC GLOBAL     Thoả thuận
# 3                  CÔNG TY CỔ PHẦN CÔNG NGHỆ SOTATEK   Tới 35 triệu
# 4                    Công ty Cổ phần Thời Trang Yody   Tới 50 triệu
# 5                         Công ty Cổ Phần Rikkeisoft  12 - 18 triệu
# 6    Công ty TNHH Công nghệ và Giải pháp CMC Sài Gòn     Thoả thuận
# 7         CÔNG TY TNHH CÔNG NGHỆ VÀ TRUYỀN THÔNG IIT    2 - 6 triệu
# 8   Công ty cổ phần Công nghệ và Giải pháp Bình Minh     Thoả thuận
# 9  CÔNG TY TNHH CÔNG NGHỆ VÀ TRUYỀN THÔNG IIT(IIT...    3 - 6 triệu
#
#                                        address                      time  \
# 0                                       Hà Nội  Còn 25 ngày để ứng tuyển
# 1                                  Hồ Chí Minh  Còn 91 ngày để ứng tuyển
# 2                                    Toàn Quốc  Còn 30 ngày để ứng tuyển
# 3                             Hà Nội: Cầu Giấy  Còn 25 ngày để ứng tuyển
# 4  Hà Nội: Thanh Xuân: Hải Dương: TP Hải Dương  Còn 30 ngày để ứng tuyển
# 5                          Hà Nội: Nam Từ Liêm  Còn 30 ngày để ứng tuyển
# 6                          Hồ Chí Minh: Quận 7  Còn 30 ngày để ứng tuyển
# 7                             Hà Nội: Cầu Giấy  Còn 25 ngày để ứng tuyển
# 8                             Hà Nội: Cầu Giấy  Còn 30 ngày để ứng tuyển
# 9                             Hà Nội: Cầu Giấy  Còn 25 ngày để ứng tuyển
#
#                                     link_description  \
# 0  https://www.topcv.vn/viec-lam/business-analyst...
# 1  https://www.topcv.vn/viec-lam/nhan-vien-lap-tr...
# 2  https://www.topcv.vn/viec-lam/net-developer-n3...
# 3  https://www.topcv.vn/viec-lam/project-manager-...
# 4  https://www.topcv.vn/viec-lam/devops-sre-chuye...
# 5  https://www.topcv.vn/viec-lam/angularjs-tu-1-5...
# 6  https://www.topcv.vn/viec-lam/it-application-s...
# 7  https://www.topcv.vn/viec-lam/thuc-tap-sinh-la...
# 8  https://www.topcv.vn/viec-lam/chuyen-vien-lap-...
# 9  https://www.topcv.vn/viec-lam/thuc-tap-lap-tri...
#
#                                          salary_info  salary_num  min_salary  \
# 0  {'num': 15.0, 'min': 10.0, 'max': 20.0, 'unit'...  15000000.0        10.0
# 1  {'num': 15.0, 'min': 10.0, 'max': 20.0, 'unit'...  15000000.0        10.0
# 2                                      {'num': None}         NaN         NaN
# 3  {'num': 35.0, 'min': None, 'max': 35.0, 'unit'...  35000000.0         NaN
# 4  {'num': 50.0, 'min': None, 'max': 50.0, 'unit'...  50000000.0         NaN
# 5  {'num': 15.0, 'min': 12.0, 'max': 18.0, 'unit'...  15000000.0        12.0
# 6                                      {'num': None}         NaN         NaN
# 7  {'num': 4.0, 'min': 2.0, 'max': 6.0, 'unit': '...   4000000.0         2.0
# 8                                      {'num': None}         NaN         NaN
# 9  {'num': 4.5, 'min': 3.0, 'max': 6.0, 'unit': '...   4500000.0         3.0
#
#    max_salary salary_unit
# 0        20.0   triệu VND
# 1        20.0   triệu VND
# 2         NaN        None
# 3        35.0   triệu VND
# 4        50.0   triệu VND
# 5        18.0   triệu VND
# 6         NaN        None
# 7         6.0   triệu VND
# 8         NaN        None
# 9         6.0   triệu VND
